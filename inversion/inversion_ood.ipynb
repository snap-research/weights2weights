# %% [markdown]
# # OOD Projection Notebook

# %%
import sys
import os 
sys.path.append(os.path.abspath(os.path.join("", "..")))
import torch
import warnings
warnings.filterwarnings("ignore")
from PIL import Image
from lora_w2w import LoRAw2w
from utils import load_models, inference, save_model_w2w, save_model_for_diffusers
from inversion import invert
device = "cuda:0"

# %% [markdown]
# # Loading Base Models

# %%
unet, vae, text_encoder, tokenizer, noise_scheduler = load_models(device)
# Out:
# Loading pipeline components...:  17%|█▋        | 1/6 [00:00<00:00,  7.38it/s]
# Loading pipeline components...: 100%|██████████| 6/6 [00:01<00:00,  3.75it/s]

# %% [markdown]
# 1) mean is 99648 dimensional tensor of the mean for each parameter in the original LoRA space.
# 2) std is 99648 dimensional tensor of the standard deviation for each parameter in the original LoRA space.
# 3) v is 99648x10000 dimensional tensor used to project or unproject the weights onto principal component representation in w2w space or to unproject back into the LoRA space.
# 4) weight_dimensions is a dictionary of the dimensionality for each LoRA in the UNet. Used to save models in Diffusers pipeline format.

# %%
mean = torch.load("../files/mean.pt").bfloat16().to(device)
std = torch.load("../files/std.pt").bfloat16().to(device)
v = torch.load("../files/V.pt").bfloat16().to(device)
weight_dimensions = torch.load("../files/weight_dimensions.pt")

# %% [markdown]
# Initialize optimization coefficients and load in. For OOD images, 1000 principal components achieves better results since it further constrains the parameters to only capture prominents features of the face rather than overfitting to low-level ones.

# %%
proj = torch.zeros(1,1000).bfloat16().to(device)
network = LoRAw2w( proj, mean, std, v[:, :1000], 
                    unet,
                    rank=1,
                    multiplier=1.0,
                    alpha=27.0,
                    train_method="xattn-strict"
                ).to(device, torch.bfloat16)

# %% [markdown]
# # Inversion

# %% [markdown]
# To run inversion, we provide a given image and an optional mask that can help guide reconstructing identity. You can provide a path to your own image and an optional mask. Refer to the folder structure for the example. If identity reconstruction or image quality is still lacking, we suggest experimenting with the number of epochs, lr, and weight_decay.

# %%
network = invert(network=network, unet=unet, vae=vae, text_encoder=text_encoder, tokenizer=tokenizer, 
                 prompt = "sks person", noise_scheduler = noise_scheduler, epochs=800, 
                 image_path = "../inversion/images/ood_image/ood", 
                 mask_path = "../inversion/images/ood_image/mask.png", device = device, 
                 lr=1, 
                 weight_decay=0)

# %% [markdown]
# Show Original Image

# %%
image = Image.open("../inversion/images/ood_image/ood/im/painting.jpeg")
image.resize((512,512)).show()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# Generate samples from inverted identity

# %%
#inference parameters
prompt = "sks person" 
negative_prompt = "low quality, blurry, unfinished" 
batch_size = 1
height = 512
width = 512
guidance_scale = 4.0
seed = 6
ddim_steps = 50
# random seed generator
generator = torch.Generator(device=device)

#run inference
image = inference(network, unet, vae, text_encoder, tokenizer, prompt, negative_prompt, guidance_scale, noise_scheduler, ddim_steps, seed, generator, device)

### display image
image = image.detach().cpu().float().permute(0, 2, 3, 1).numpy()[0]
image = Image.fromarray((image * 255).round().astype("uint8"))
image.show()
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# 100%|██████████| 51/51 [00:02<00:00, 23.94it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# Save model (just the 1000 coefficients)

# %%
save_model_w2w(network, path="../output/ood_inversion1.pt")

# %% [markdown]
# You can also save it in a format compatible with Diffusers pipelines

# %%
save_model_for_diffusers(network,std, mean, v[:, :1000], weight_dimensions, path="../output/ood_inversion1_diffusers.pt")
